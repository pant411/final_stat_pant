# %%
#! -*- coding: UTF8 -*-
import os
os.chdir(os.getcwd())

# %% [markdown]
# ## Import Module

# %%
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
sns.set(font='TH Sarabun New')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
df_train = pd.read_excel('process_data/part3_happiness.xlsx',sheet_name="TrainData") #ตัวอย่าง
df_train.head()
# Out:
#        country       pop           gdp  unemployment     primary   secondary  \
# 0  Afghanistan  33370804  2.049713e+10          7.91  105.919708   52.582901
# 1      Albania   2889104  1.322815e+10         18.05  104.108040   97.684868
# 2      Algeria  38923688  2.138100e+11         10.21  118.502808         NaN
# 3       Angola  26941773  1.457120e+11          9.58         NaN         NaN
# 4    Argentina  42669500  5.263200e+11          7.27  111.459671  106.035561
#
#     tertiary  mortality_infant_rate  life_expectancy  physician  ...  \
# 0   8.230680                   55.2           62.966     0.2983  ...
# 1  65.782967                    8.8           77.813        NaN  ...
# 2  34.481819                   21.9           75.878        NaN  ...
# 3        NaN                   60.5           58.776        NaN  ...
# 4  80.995811                   10.8           75.913        NaN  ...
#
#         co2  forest_land  broadband      mobile        power  birth_rate  \
# 0  0.234037     1.850994   0.004495   55.159515          NaN      35.706
# 1  1.806789    28.750511   7.180321  115.997935  2309.366503      12.259
# 2  3.566209     0.818057   4.109816  111.238610  1362.871884      25.538
# 3  1.285365    56.098301   0.325702   52.158983   312.228895      43.182
# 4  4.216361    10.713819  15.290428  143.615832  3074.702071      17.698
#
#    age_15_64     senior  Social support  Happiness
# 0  51.907836   2.451575        0.525568          0
# 1  68.599025  12.180692        0.625587          0
# 2  66.002598   5.733120        0.818189          2
# 3  50.519797   2.303044        0.754615          0
# 4  64.015470  10.616401        0.917870          2
#
# [5 rows x 21 columns]

# %%
sns.heatmap(df_train.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df_test = pd.read_excel('process_data/part3_happiness.xlsx',sheet_name="TestData") #ตัวอย่าง
df_test.head()
# Out:
#        country       pop           gdp  unemployment     primary   secondary  \
# 0  Afghanistan  36296111  1.875347e+10         11.18  102.175789   53.643200
# 1      Albania   2873457  1.301969e+10         13.62  107.046600   95.265892
# 2      Algeria  41389174  1.700970e+11         13.57  111.764481         NaN
# 3    Argentina  44044811  6.436290e+11          8.35  109.741463  108.733597
# 4      Armenia   2944789  1.152746e+10         17.70   94.083519         NaN
#
#     tertiary  mortality_infant_rate  life_expectancy  physician  ...  \
# 0        NaN                   49.6           64.130        NaN  ...
# 1  57.375259                    8.4           78.333        NaN  ...
# 2  47.646832                   20.9           76.499     1.7879  ...
# 3  89.958519                    9.2           76.372     3.9901  ...
# 4  52.251530                   11.6           74.797     4.4023  ...
#
#         co2  forest_land  broadband      mobile  power  birth_rate  age_15_64  \
# 0  0.203328     1.850994   0.025297   65.929134    NaN      33.211  53.763223
# 1  1.948872    28.792062  10.526845  125.710352    NaN      11.934  68.642614
# 2  3.505748     0.815790   7.756294  110.767246    NaN      24.846  64.183205
# 3  4.089472    10.559837  17.849997  140.877124    NaN      17.205  64.083523
# 4  1.806581    11.559536  10.707687  118.464231    NaN      14.298  68.448966
#
#       senior  Social support  Happiness
# 0   2.554251        0.490880          0
# 1  13.329073        0.637698          0
# 2   6.177205        0.806754          1
# 3  10.989707        0.906699          1
# 4  11.096645        0.697925          0
#
# [5 rows x 21 columns]
