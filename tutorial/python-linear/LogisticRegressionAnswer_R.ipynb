# %%
setwd(getwd())

# %%
df <- read.csv("cancer.csv", sep=",", header=T, 
               fileEncoding="UTF-8-BOM")
attach(df)
df
# Out:
#     Age NumPregnancies Smokes YrOfSmokes SmokesPacks Contraceptives
# 1   18  1              0       0.000000   0.0000000  0
# 2   15  1              0       0.000000   0.0000000  0
# 3   34  1              0       0.000000   0.0000000  0
# 4   52  4              1      37.000000  37.0000000  1
# 5   46  4              0       0.000000   0.0000000  1
# 6   42  2              0       0.000000   0.0000000  0
# 7   51  6              1      34.000000   3.4000000  0
# 8   26  3              0       0.000000   0.0000000  1
# 9   45  5              0       0.000000   0.0000000  0
# 10  44  4              0       0.000000   0.0000000  1
# 11  27  3              0       0.000000   0.0000000  1
# 12  45  6              0       0.000000   0.0000000  1
# 13  44  2              0       0.000000   0.0000000  1
# 14  43  5              0       0.000000   0.0000000  0
# 15  40  2              0       0.000000   0.0000000  1
# 16  41  3              0       0.000000   0.0000000  1
# ...

# %%
Age <- Age
NumPregnancies <- NumPregnancies
Smokes <- Smokes
YrOfSmokes <- YrOfSmokes
SmokesPacks <- SmokesPacks
Contraceptives <- Contraceptives
YrOfContraceptives <- YrOfContraceptives
Biopsy <- Biopsy

# %%
model <- lm(Biopsy ~ Age+NumPregnancies+Smokes+YrOfSmokes+SmokesPacks+Contraceptives+YrOfContraceptives+Biopsy)
summary(model)
# Out:
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 8 in model.matrix: no columns are assigned”
# Call:
# lm(formula = Biopsy ~ Age + NumPregnancies + Smokes + YrOfSmokes +
#     SmokesPacks + Contraceptives + YrOfContraceptives + Biopsy)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41158 -0.09674 -0.05933 -0.01586  0.97388
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)         0.001898   0.106126   0.018  0.98576
# Age                 0.002299   0.003698   0.622  0.53511
# NumPregnancies     -0.026356   0.019925  -1.323  0.18809
# Smokes             -0.053802   0.096391  -0.558  0.57763
# YrOfSmokes          0.027244   0.008908   3.058  0.00267 **
# SmokesPacks        -0.026149   0.009345  -2.798  0.00587 **
# Contraceptives      0.056709   0.055453   1.023  0.30824
# ...
